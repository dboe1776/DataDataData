# %% [markdown]
# # Data Frame Demo
# ---

# %% [markdown]
# Begin by importing the pandas module

# %%
import pandas as pd

# %% [markdown]
# First, let's look at the leading cause of death data set. We begin by reading the .csv file into a DataFrame variable called DF (this is pretty much a de factor standard variable name for a genaric DataFrame).  Note that we pass a second argument ($\textit{na_vals='.'}$) to the $\textit{read_csv()}$ function; this just tells the function to treat a string that matches '.' as a NAN value.  This will later on make it easier for us to convert columns from strings to numeric types.

# %%
file_name='New_York_City_Leading_Causes_of_Death'
DF=pd.read_csv(file_name+'.csv',na_values='.')

# %%
DF
# Out:
#       Year                                      Leading Cause Sex  \
# 0     2010            Influenza (Flu) and Pneumonia (J09-J18)   F
# 1     2008  Accidents Except Drug Posioning (V01-X39, X43,...   F
# 2     2013  Accidents Except Drug Posioning (V01-X39, X43,...   M
# 3     2010          Cerebrovascular Disease (Stroke: I60-I69)   M
# 4     2009                 Assault (Homicide: Y87.1, X85-Y09)   M
# ...    ...                                                ...  ..
# 1089  2012            Influenza (Flu) and Pneumonia (J09-J18)   F
# 1090  2014  Accidents Except Drug Posioning (V01-X39, X43,...   F
# 1091  2009              Malignant Neoplasms (Cancer: C00-C97)   M
# 1092  2009    Intentional Self-Harm (Suicide: X60-X84, Y87.0)   M
# 1093  2013  Essential Hypertension and Renal Diseases (I10...   M
#
#           Race Ethnicity  Deaths  Death Rate  Age Adjusted Death Rate
# 0               Hispanic   228.0        18.7                     23.1
# 1               Hispanic    68.0         5.8                      6.6
# 2     White Non-Hispanic   271.0        20.1                     17.9
# 3               Hispanic   140.0        12.3                     21.4
# 4     Black Non-Hispanic   255.0        30.0                     30.0
# ...                  ...     ...         ...                      ...
# 1089  Not Stated/Unknown     6.0         NaN                      NaN
# 1090  White Non-Hispanic   169.0        11.9                      7.4
# 1091  White Non-Hispanic  3236.0       240.5                    205.6
# 1092  White Non-Hispanic   191.0        14.2                     13.0
# 1093  Black Non-Hispanic   148.0        17.2                     20.9
#
# [1094 rows x 7 columns]

# %% [markdown]
# Next, let's take a look at the group by method in Pandas.  This is one of the more powerful functions available in Pandas with countless applications. In general, it allows us to specifiy a certain column to form groups where each group consists of all the duplicate values in that column.  Now, the real power of this function lies in it's abiltiy to then perform any sort of function, group-wise to each column of the DataFrame. Let's say, for instance, that want to group the data by Year and then calculate the total deaths per year from all causes.

# %%
DF.groupby(by='Year').sum().Deaths
# Out:
# Year
# 2007    53996.0
# 2008    54138.0
# 2009    52820.0
# 2010    52505.0
# 2011    52726.0
# 2012    52420.0
# 2013    53387.0
# 2014    53006.0
# Name: Deaths, dtype: float64

# %% [markdown]
# The syntax is pretty straightforward.  We just use the DataFrame to access the $\textit{groupby()}$ method and then pass $\textit{groupby()}$ the column name that we want to form groups from.  Next, we set the function that we want to apply to each group.  In this case, we want to sum up all the deaths, so we just use the $\textit{sum()}$ function.  Finally, I just want to look at the Deaths column, so I specify this once again by using the dot operator.
#
# <br>
# <br>
# Next, let's try the test case of the project.  We need to find the total number of deaths from each cause of death over the entire 7 year period.  Basically, we just need to group by $\textit{Leading Cause}$ and then find the total number of deaths from each group by summing.

# %%
DF.groupby(by='Leading Cause').sum().sort_values('Deaths',ascending=False)
# Out:
#                                                       Year    Deaths  \
# Leading Cause
# Diseases of Heart (I00-I09, I11, I13, I20-I51)      193008  147551.0
# Malignant Neoplasms (Cancer: C00-C97)               193008  106367.0
# All Other Causes                                    193008   77999.0
# Influenza (Flu) and Pneumonia (J09-J18)             193008   18678.0
# Diabetes Mellitus (E10-E14)                         184970   13794.0
# Chronic Lower Respiratory Diseases (J40-J47)        176923   13214.0
# Cerebrovascular Disease (Stroke: I60-I69)           180949   12941.0
# Accidents Except Drug Posioning (V01-X39, X43, ...  160828    7467.0
# Essential Hypertension and Renal Diseases (I10,...  150794    6955.0
# Human Immunodeficiency Virus Disease (HIV: B20-...   86438    5436.0
# Mental and Behavioral Disorders due to Accident...   78407    4284.0
# Alzheimer's Disease (G30)                            64355    2980.0
# Assault (Homicide: Y87.1, X85-Y09)                   40193    2102.0
# Intentional Self-Harm (Suicide: X60-X84, Y87.0)      76402    2086.0
# Chronic Liver Disease and Cirrhosis (K70, K73)       58306    1505.0
# Nephritis, Nephrotic Syndrome and Nephrisis (N0...   34175     753.0
# Septicemia (A40-A41)                                 26144     641.0
# Certain Conditions originating in the Perinatal...   52273     197.0
# Congenital Malformations, Deformations, and Chr...   16087      22.0
# Viral Hepatitis (B15-B19)                            10052      21.0
# Insitu or Benign / Uncertain Neoplasms (D00-D48)     10042       5.0
# Aortic Aneurysm and Dissection (I71)                  6027       0.0
# Atherosclerosis (I70)                                 6026       0.0
# Mental and Behavioral Disorders due to Use of A...    4017       0.0
# Parkinson's Disease (G20)                             2011       0.0
# Tuberculosis (A16-A19)                                2011       0.0
#
#                                                     Death Rate  \
# Leading Cause
# Diseases of Heart (I00-I09, I11, I13, I20-I51)         12758.5
# Malignant Neoplasms (Cancer: C00-C97)                   9587.0
# All Other Causes                                        6976.7
# Influenza (Flu) and Pneumonia (J09-J18)                 1656.9
# Diabetes Mellitus (E10-E14)                             1298.4
# Chronic Lower Respiratory Diseases (J40-J47)            1154.2
# Cerebrovascular Disease (Stroke: I60-I69)               1206.0
# Accidents Except Drug Posioning (V01-X39, X43, ...       693.5
# Essential Hypertension and Renal Diseases (I10,...       652.5
# Human Immunodeficiency Virus Disease (HIV: B20-...       545.3
# Mental and Behavioral Disorders due to Accident...       344.1
# Alzheimer's Disease (G30)                                236.6
# Assault (Homicide: Y87.1, X85-Y09)                       241.1
# Intentional Self-Harm (Suicide: X60-X84, Y87.0)          205.9
# Chronic Liver Disease and Cirrhosis (K70, K73)           139.7
# Nephritis, Nephrotic Syndrome and Nephrisis (N0...        77.5
# Septicemia (A40-A41)                                      48.7
# Certain Conditions originating in the Perinatal...         6.8
# Congenital Malformations, Deformations, and Chr...         2.8
# Viral Hepatitis (B15-B19)                                  2.5
# Insitu or Benign / Uncertain Neoplasms (D00-D48)           0.0
# Aortic Aneurysm and Dissection (I71)                       0.0
# Atherosclerosis (I70)                                      0.0
# Mental and Behavioral Disorders due to Use of A...         0.0
# Parkinson's Disease (G20)                                  0.0
# Tuberculosis (A16-A19)                                     0.0
#
#                                                     Age Adjusted Death Rate
# Leading Cause
# Diseases of Heart (I00-I09, I11, I13, I20-I51)                      12418.7
# Malignant Neoplasms (Cancer: C00-C97)                                9677.0
# All Other Causes                                                     7094.1
# Influenza (Flu) and Pneumonia (J09-J18)                              1731.1
# Diabetes Mellitus (E10-E14)                                          1401.6
# Chronic Lower Respiratory Diseases (J40-J47)                         1174.4
# Cerebrovascular Disease (Stroke: I60-I69)                            1228.9
# Accidents Except Drug Posioning (V01-X39, X43, ...                    700.8
# Essential Hypertension and Renal Diseases (I10,...                    646.6
# Human Immunodeficiency Virus Disease (HIV: B20-...                    545.0
# Mental and Behavioral Disorders due to Accident...                    333.6
# Alzheimer's Disease (G30)                                             173.8
# Assault (Homicide: Y87.1, X85-Y09)                                    241.5
# Intentional Self-Harm (Suicide: X60-X84, Y87.0)                       193.8
# Chronic Liver Disease and Cirrhosis (K70, K73)                        168.7
# Nephritis, Nephrotic Syndrome and Nephrisis (N0...                     73.3
# Septicemia (A40-A41)                                                   34.7
# Certain Conditions originating in the Perinatal...                      8.2
# Congenital Malformations, Deformations, and Chr...                      3.0
# Viral Hepatitis (B15-B19)                                               2.5
# Insitu or Benign / Uncertain Neoplasms (D00-D48)                        0.0
# Aortic Aneurysm and Dissection (I71)                                    0.0
# Atherosclerosis (I70)                                                   0.0
# Mental and Behavioral Disorders due to Use of A...                      0.0
# Parkinson's Disease (G20)                                               0.0
# Tuberculosis (A16-A19)                                                  0.0

# %% [markdown]
# And there it is, we grouped by Cause and then sum all the rows of each column, so we do end up with some nonsensical results by summing years and death rates; however, the $\textit{Deaths}$ column is exactly what we are looking for - The total number of deaths from each particular cause over the entire seven year sample period. Note that I appended one additional function to the code; $\textit{sort_values()}$ just sorts the data by the specified column (Deaths in this case) in descending or ascending fashion.
# <br>
# <br>
# Note that the above process returns a new smaller DataFrame object. This is not what we want, because the project goals ask us to basically print a string in .csv format.  Naturally, pandas has a built-in function just for this.

# %%
print(DF.groupby(by='Leading Cause').sum().sort_values('Deaths',ascending=False).Deaths.to_csv())
# Out:
# Leading Cause,Deaths
# "Diseases of Heart (I00-I09, I11, I13, I20-I51)",147551.0
# Malignant Neoplasms (Cancer: C00-C97),106367.0
# All Other Causes,77999.0
# Influenza (Flu) and Pneumonia (J09-J18),18678.0
# Diabetes Mellitus (E10-E14),13794.0
# Chronic Lower Respiratory Diseases (J40-J47),13214.0
# Cerebrovascular Disease (Stroke: I60-I69),12941.0
# "Accidents Except Drug Posioning (V01-X39, X43, X45-X59, Y85-Y86)",7467.0
# "Essential Hypertension and Renal Diseases (I10, I12)",6955.0
# Human Immunodeficiency Virus Disease (HIV: B20-B24),5436.0
# "Mental and Behavioral Disorders due to Accidental Poisoning and Other Psychoactive Substance Use (F11-F16, F18-F19, X40-X42, X44)",4284.0
# Alzheimer's Disease (G30),2980.0
# "Assault (Homicide: Y87.1, X85-Y09)",2102.0
# "Intentional Self-Harm (Suicide: X60-X84, Y87.0)",2086.0
# "Chronic Liver Disease and Cirrhosis (K70, K73)",1505.0
# "Nephritis, Nephrotic Syndrome and Nephrisis (N00-N07, N17-N19, N25-N27)",753.0
# Septicemia (A40-A41),641.0
# Certain Conditions originating in the Perinatal Period (P00-P96),197.0
# "Congenital Malformations, Deformations, and Chromosomal Abnormalities (Q00-Q99)",22.0
# Viral Hepatitis (B15-B19),21.0
# Insitu or Benign / Uncertain Neoplasms (D00-D48),5.0
# Aortic Aneurysm and Dissection (I71),0.0
# Atherosclerosis (I70),0.0
# Mental and Behavioral Disorders due to Use of Alcohol (F10),0.0
# Parkinson's Disease (G20),0.0
# Tuberculosis (A16-A19),0.0
